# %% [markdown]
# # Пример работы алгоритма

# %% [markdown]
# Для иллюстрации работы алгоритма разобъем демонстрацию функциональности метода check_image() на два сопутствующих шага: считывание набора исходных предметов и работа непосредственно с входным изображением.

# %%
import os
from intellegent_placer import read_objects, read_image

# %% [markdown]
# В первую очередь создадим набор исходных предметов, выделяя их на изображениях и сохраняя необходимые характеристики (имя предмета, свойства, особые точки, дескрипторы) в класс Object.

# %% [markdown]
# Проиллюстрируем три этапа процесса:
# 1. Исходный вид изображений
# 2. Выделение объектов с помощью масок
# 3. Обрезка изображения по области, ограничивающей, объект

# %%
read_objects()

# %% [markdown]
# Проверим работу алгоритма для входного изображения Example.jpg. Известно, что адаптер, отображенный на данном изображении, вмещается в заданный многоугольник.

# %%
image_path = os.path.abspath("Images\\Example.jpg")
print(f"Objects fit in the polygon: {read_image(image_path)}")
# Out:
# The matching object is Adapter with value 0.723404255319149
# Objects fit in the polygon: True

# %% [markdown]
# Таким образом, алгоритм правильно распознал предметы на входном изображении и ответил на вопрос о возможности поместить их в заданный многоугольник.
